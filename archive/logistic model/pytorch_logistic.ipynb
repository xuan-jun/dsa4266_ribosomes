# %%
# general purpose libraries
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# torch libraries
import torch
import torch.nn as nn
import torchmetrics
from torcheval.metrics.functional import binary_auprc

# model libraries
from neural_net_pre_process import RNAData

# %%
DATA_PATH = os.path.join(".", "data", "dataset0.json.gz")
LABEL_PATH = os.path.join(".", "data", "data.info")
BATCH_SIZE = 128
READ_SIZE = 20
TRAIN_SIZE = 0.8  # Specify the training size if you're using train-test split

rna_data = RNAData(data_path=DATA_PATH, label_path=LABEL_PATH, batch_size=BATCH_SIZE, read_size=READ_SIZE, train=True, train_size=TRAIN_SIZE)
# Out:
# Currently pre processing ...
# Pre processing done!
# Currently labelling ...
# Labelling done
# Currently Splitting ...
# Splitting done
# Currently encoding ...
# Encoding done

# %%
rna_data

# %%
# Switch to train mode
rna_data.train_mode()
    
# Get training data
train_data_loader = rna_data.data_loader()
    
 # Extract features (X) and labels (y) for training
X_train, y_train = zip(*[batch for batch in train_data_loader])
X_train = torch.cat(X_train)
y_train = torch.cat(y_train)

# %%
# Switch to eval mode
rna_data.eval_mode()

# Get test data
test_data_loader = rna_data.data_loader()
    
# Extract features (X) and labels (y) for testing
X_test, y_test = zip(*[batch for batch in test_data_loader])
X_test = torch.cat(X_test)
y_test = torch.cat(y_test)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# torch.Size([97499, 20, 12])
# torch.Size([97499])
# torch.Size([24339, 20, 12])
# torch.Size([24339])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_curve, auc, precision_recall_curve, average_precision_score, roc_auc_score
import matplotlib.pyplot as plt

def logistic_regression(X_train, y_train, X_test, y_test, c, reg):
    """
    Perform logistic regression, evaluate the model, and plot ROC and PRC curves.

    Parameters:
    X_train (torch.Tensor): Training features.
    y_train (torch.Tensor): Training labels.
    X_test (torch.Tensor): Testing features.
    y_test (torch.Tensor): Testing labels.

    Returns:
    None
    """

    # Fit the logistic regression model
    model = LogisticRegression(solver="saga", C=c, penalty=reg)
    model.fit(X_train.view(X_train.size(0), -1), y_train)  # Flatten X_train to 2D

    # Predict probabilities
    y_pred = model.predict(X_test.view(X_test.size(0), -1))  # Flatten X_test to 2D
    y_pred_prob = model.predict_proba(X_test.view(X_test.size(0), -1))[:, 1]

    # Print classification report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    # Compute Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)

    # Calculate the area under the Precision-Recall Curve (PRC)
    prc_auc = average_precision_score(y_test, y_pred_prob)

    # Print ROC AUC score
    print('ROC AUC Score:', roc_auc)

    # Print PRC score
    print('PRC AUC Score:', prc_auc)

    # Plot ROC and PRC curves
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')

    plt.subplot(1, 2, 2)
    plt.plot(recall, precision, color='blue', lw=2, label='PRC')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend(loc='lower left')

    plt.tight_layout()
    plt.show()

# %%
logistic_regression(X_train, y_train, X_test, y_test, 1, None)
# Out:
# c:\Users\jonas\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.75      0.85     23107
#            1       0.13      0.72      0.22      1232
#
#     accuracy                           0.75     24339
#    macro avg       0.56      0.73      0.54     24339
# weighted avg       0.94      0.75      0.82     24339
#
# ROC AUC Score: 0.8190700841764371
# PRC AUC Score: 0.3046434957160937

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, precision_recall_curve, average_precision_score, roc_auc_score

def logistic_regression(X_train, y_train, X_test, y_test, c, reg):
    """
    Perform logistic regression, evaluate the model, and plot ROC and PRC curves.

    Parameters:
    X_train (torch.Tensor): Training features.
    y_train (torch.Tensor): Training labels.
    X_test (torch.Tensor): Testing features.
    y_test (torch.Tensor): Testing labels.
    c (list): List of regularization strengths to search.
    reg (list): List of regularization types to search (e.g., 'l1', 'l2').

    Returns:
    None
    """

    # Define the hyperparameters to search
    param_grid = {'C': c, 'penalty': reg}

    # Create a logistic regression model
    model = LogisticRegression(solver="saga")

    # Create a grid search cross-validation model
    grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, scoring='average_precision')

    # Fit the grid search model
    grid_search.fit(X_train.view(X_train.size(0), -1), y_train)

    # Get the best hyperparameters from the grid search
    best_c = grid_search.best_params_['C']
    best_reg = grid_search.best_params_['penalty']

    # Fit the logistic regression model with the best hyperparameters
    best_model = LogisticRegression(solver="saga", C=best_c, penalty=best_reg)
    best_model.fit(X_train.view(X_train.size(0), -1), y_train)

    # Predict probabilities
    y_pred = best_model.predict(X_test.view(X_test.size(0), -1))  # Flatten X_test to 2D
    y_pred_prob = best_model.predict_proba(X_test.view(X_test.size(0), -1))[:, 1]

    # Print classification report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    # Compute Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)

    # Calculate the area under the Precision-Recall Curve (PRC)
    prc_auc = average_precision_score(y_test, y_pred_prob)

    # Print ROC AUC score
    print('ROC AUC Score:', roc_auc)

    # Print PRC score
    print('PRC AUC Score:', prc_auc)

    # Plot ROC and PRC curves
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')

    plt.subplot(1, 2, 2)
    plt.plot(recall, precision, color='blue', lw=2, label='PRC')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend(loc='lower left')

    plt.tight_layout()
    plt.show()

    return grid_search

def visualize_grid_search_results(grid_search):
    results = grid_search.cv_results_

    # Extract the hyperparameters and performance scores
    c_values = np.array(results['param_C'].data, dtype=float)
    reg_types = results['param_penalty']
    mean_test_scores = results['mean_test_score']
    
    # Create a heatmap to visualize the mean test scores
    unique_c_values = np.unique(c_values)
    unique_reg_types = np.unique(reg_types)

    heatmap_data = np.zeros((len(unique_reg_types), len(unique_c_values)))

    for i, c in enumerate(unique_c_values):
        for j, reg in enumerate(unique_reg_types):
            mask = (c_values == c) & (reg_types == reg)
            score = mean_test_scores[mask]
            heatmap_data[j, i] = score[0]  # Assuming there's only one score per combination

    # Create a table to show mean test scores
    results_df = pd.DataFrame(results)
    relevant_columns = ['param_C', 'param_penalty', 'mean_test_score', 'std_test_score']
    table = results_df[relevant_columns].sort_values(by='mean_test_score', ascending=False)

    print("Grid Search Results Table:")
    print(table)

# %%
c_values = [0.1, 1.0, 10.0]  # List of regularization strengths to search
reg_types = ['l1', 'l2']  # List of regularization types to search

gs = logistic_regression(X_train, y_train, X_test, y_test, c_values, reg_types)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.75      0.85     23107
#            1       0.13      0.72      0.22      1232
#
#     accuracy                           0.75     24339
#    macro avg       0.56      0.73      0.54     24339
# weighted avg       0.94      0.75      0.82     24339
#
# ROC AUC Score: 0.819083011051354
# PRC AUC Score: 0.30460669238335636

# %%
visualize_grid_search_results(gs)
# Out:
# Grid Search Results Table:
#   param_C param_penalty  mean_test_score  std_test_score
# 0     0.1            l1         0.826319        0.003589
# 2     1.0            l1         0.826293        0.003581
# 4    10.0            l1         0.826293        0.003580
# 1     0.1            l2         0.826293        0.003580
# 5    10.0            l2         0.826293        0.003580
# 3     1.0            l2         0.826292        0.003580

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

def xgboost_classification(X_train, y_train, X_test, y_test, params):
    """
    Perform XGBoost classification, evaluate the model, and print a classification report.
    Plot ROC and PRC curves.

    Parameters:
    X_train (torch.Tensor): Training features.
    y_train (torch.Tensor): Training labels.
    X_test (torch.Tensor): Testing features.
    y_test (torch.Tensor): Testing labels.
    params (dict): Dictionary of XGBoost hyperparameters to search.

    Returns:
    None
    """

    # Create an XGBoost classifier
    xgb_classifier = xgb.XGBClassifier()

    # Create a grid search cross-validation model
    grid_search = GridSearchCV(xgb_classifier, params, cv=5, n_jobs=-1, scoring='average_precision', verbose=2)

    # Fit the grid search model
    grid_search.fit(X_train.view(X_train.size(0), -1), y_train)

    # Get the best hyperparameters from the grid search
    best_params = grid_search.best_params_

    # Create an XGBoost classifier with the best hyperparameters
    best_xgb_classifier = xgb.XGBClassifier(**best_params)

    # Set the evaluation metrics for AUC and AUCPR
    eval_metrics = ["auc", "aucpr"]

    # Fit the XGBoost model with the best hyperparameters and evaluation metrics
    best_xgb_classifier.fit(
        X_train.view(X_train.size(0), -1),
        y_train,
        eval_metric=eval_metrics,  # Use AUC and AUCPR as evaluation metrics
        eval_set=[(X_test.view(X_test.size(0), -1), y_test)]
    )

    # Predict labels
    y_pred = best_xgb_classifier.predict(X_test.view(X_test.size(0), -1))

    # Print classification report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, best_xgb_classifier.predict_proba(X_test.view(X_test.size(0), -1))[:, 1])
    roc_auc = auc(fpr, tpr)

    # Compute Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, best_xgb_classifier.predict_proba(X_test.view(X_test.size(0), -1))[:, 1])
    prc_auc = average_precision_score(y_test, best_xgb_classifier.predict_proba(X_test.view(X_test.size(0), -1))[:, 1])

    # Print ROC AUC score
    print('ROC AUC Score:', roc_auc)

    # Print PRC AUC score
    print('PRC AUC Score:', prc_auc)

    # Plot ROC and PRC curves
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')

    plt.subplot(1, 2, 2)
    plt.plot(recall, precision, color='blue', lw=2, label='PRC')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend(loc='lower left')

    plt.tight_layout()
    plt.show()

    return grid_search

# %%
# Define XGBoost hyperparameters to search
xgboost_params = {
    'subsample': [1],
    'learning_rate': [0.3],
    'max_depth': [6]
}

# Call the XGBoost classification function
xgboost_grid_search = xgboost_classification(X_train, y_train, X_test, y_test, xgboost_params)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\jonas\anaconda3\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.83537	validation_0-aucpr:0.26560
# [1]	validation_0-auc:0.85226	validation_0-aucpr:0.32597
# [2]	validation_0-auc:0.85542	validation_0-aucpr:0.33627
# [3]	validation_0-auc:0.86335	validation_0-aucpr:0.36346
# [4]	validation_0-auc:0.86817	validation_0-aucpr:0.37946
# [5]	validation_0-auc:0.87277	validation_0-aucpr:0.38996
# [6]	validation_0-auc:0.87628	validation_0-aucpr:0.40241
# [7]	validation_0-auc:0.87874	validation_0-aucpr:0.41532
# [8]	validation_0-auc:0.88181	validation_0-aucpr:0.42662
# [9]	validation_0-auc:0.88443	validation_0-aucpr:0.43723
# [10]	validation_0-auc:0.88631	validation_0-aucpr:0.44313
# [11]	validation_0-auc:0.88759	validation_0-aucpr:0.44757
# [12]	validation_0-auc:0.88924	validation_0-aucpr:0.45149
# [13]	validation_0-auc:0.89012	validation_0-aucpr:0.45584
# [14]	validation_0-auc:0.89128	validation_0-aucpr:0.45894
# [15]	validation_0-auc:0.89253	validation_0-aucpr:0.46432
# [16]	validation_0-auc:0.89355	validation_0-aucpr:0.46713
# [17]	validation_0-auc:0.89488	validation_0-aucpr:0.46828
# [18]	validation_0-auc:0.89520	validation_0-aucpr:0.46929
# [19]	validation_0-auc:0.89544	validation_0-aucpr:0.47195
# [20]	validation_0-auc:0.89599	validation_0-aucpr:0.47248
# [21]	validation_0-auc:0.89615	validation_0-aucpr:0.47520
# [22]	validation_0-auc:0.89603	validation_0-aucpr:0.47516
# [23]	validation_0-auc:0.89640	validation_0-aucpr:0.47690
# [24]	validation_0-auc:0.89729	validation_0-aucpr:0.48165
# [25]	validation_0-auc:0.89751	validation_0-aucpr:0.47942
# [26]	validation_0-auc:0.89812	validation_0-aucpr:0.48057
# [27]	validation_0-auc:0.89870	validation_0-aucpr:0.48021
# [28]	validation_0-auc:0.89894	validation_0-aucpr:0.48068
# [29]	validation_0-auc:0.89968	validation_0-aucpr:0.48263
# [30]	validation_0-auc:0.90018	validation_0-aucpr:0.48430
# [31]	validation_0-auc:0.90025	validation_0-aucpr:0.48498
# [32]	validation_0-auc:0.90041	validation_0-aucpr:0.48589
# [33]	validation_0-auc:0.90071	validation_0-aucpr:0.48557
# [34]	validation_0-auc:0.90100	validation_0-aucpr:0.48575
# [35]	validation_0-auc:0.90140	validation_0-aucpr:0.48653
# [36]	validation_0-auc:0.90123	validation_0-aucpr:0.48624
# [37]	validation_0-auc:0.90139	validation_0-aucpr:0.48668
# [38]	validation_0-auc:0.90129	validation_0-aucpr:0.48676
# [39]	validation_0-auc:0.90107	validation_0-aucpr:0.48605
# [40]	validation_0-auc:0.90060	validation_0-aucpr:0.48608
# [41]	validation_0-auc:0.90081	validation_0-aucpr:0.48596
# [42]	validation_0-auc:0.90105	validation_0-aucpr:0.48654
# [43]	validation_0-auc:0.90107	validation_0-aucpr:0.48702
# [44]	validation_0-auc:0.90072	validation_0-aucpr:0.48610
# [45]	validation_0-auc:0.90111	validation_0-aucpr:0.48750
# [46]	validation_0-auc:0.90131	validation_0-aucpr:0.48725
# [47]	validation_0-auc:0.90141	validation_0-aucpr:0.48800
# [48]	validation_0-auc:0.90166	validation_0-aucpr:0.48820
# [49]	validation_0-auc:0.90148	validation_0-aucpr:0.48769
# [50]	validation_0-auc:0.90122	validation_0-aucpr:0.48734
# [51]	validation_0-auc:0.90119	validation_0-aucpr:0.48622
# [52]	validation_0-auc:0.90130	validation_0-aucpr:0.48534
# [53]	validation_0-auc:0.90151	validation_0-aucpr:0.48487
# [54]	validation_0-auc:0.90127	validation_0-aucpr:0.48467
# [55]	validation_0-auc:0.90143	validation_0-aucpr:0.48464
# [56]	validation_0-auc:0.90130	validation_0-aucpr:0.48447
# [57]	validation_0-auc:0.90141	validation_0-aucpr:0.48421
# [58]	validation_0-auc:0.90176	validation_0-aucpr:0.48481
# [59]	validation_0-auc:0.90139	validation_0-aucpr:0.48449
# [60]	validation_0-auc:0.90154	validation_0-aucpr:0.48432
# [61]	validation_0-auc:0.90157	validation_0-aucpr:0.48314
# [62]	validation_0-auc:0.90170	validation_0-aucpr:0.48333
# [63]	validation_0-auc:0.90189	validation_0-aucpr:0.48346
# [64]	validation_0-auc:0.90199	validation_0-aucpr:0.48316
# [65]	validation_0-auc:0.90211	validation_0-aucpr:0.48274
# [66]	validation_0-auc:0.90236	validation_0-aucpr:0.48371
# [67]	validation_0-auc:0.90252	validation_0-aucpr:0.48375
# [68]	validation_0-auc:0.90292	validation_0-aucpr:0.48405
# [69]	validation_0-auc:0.90334	validation_0-aucpr:0.48473
# [70]	validation_0-auc:0.90313	validation_0-aucpr:0.48406
# [71]	validation_0-auc:0.90270	validation_0-aucpr:0.48325
# [72]	validation_0-auc:0.90277	validation_0-aucpr:0.48267
# [73]	validation_0-auc:0.90259	validation_0-aucpr:0.48252
# [74]	validation_0-auc:0.90271	validation_0-aucpr:0.48297
# [75]	validation_0-auc:0.90234	validation_0-aucpr:0.48243
# [76]	validation_0-auc:0.90255	validation_0-aucpr:0.48250
# [77]	validation_0-auc:0.90259	validation_0-aucpr:0.48229
# [78]	validation_0-auc:0.90257	validation_0-aucpr:0.48272
# [79]	validation_0-auc:0.90232	validation_0-aucpr:0.48284
# [80]	validation_0-auc:0.90226	validation_0-aucpr:0.48254
# [81]	validation_0-auc:0.90245	validation_0-aucpr:0.48291
# [82]	validation_0-auc:0.90249	validation_0-aucpr:0.48254
# [83]	validation_0-auc:0.90250	validation_0-aucpr:0.48275
# [84]	validation_0-auc:0.90225	validation_0-aucpr:0.48240
# [85]	validation_0-auc:0.90229	validation_0-aucpr:0.48147
# [86]	validation_0-auc:0.90216	validation_0-aucpr:0.48083
# [87]	validation_0-auc:0.90211	validation_0-aucpr:0.47983
# [88]	validation_0-auc:0.90224	validation_0-aucpr:0.48001
# [89]	validation_0-auc:0.90244	validation_0-aucpr:0.48022
# [90]	validation_0-auc:0.90263	validation_0-aucpr:0.48079
# [91]	validation_0-auc:0.90255	validation_0-aucpr:0.48096
# [92]	validation_0-auc:0.90252	validation_0-aucpr:0.48143
# [93]	validation_0-auc:0.90262	validation_0-aucpr:0.48395
# [94]	validation_0-auc:0.90281	validation_0-aucpr:0.48507
# [95]	validation_0-auc:0.90262	validation_0-aucpr:0.48458
# [96]	validation_0-auc:0.90271	validation_0-aucpr:0.48494
# [97]	validation_0-auc:0.90262	validation_0-aucpr:0.48490
# [98]	validation_0-auc:0.90250	validation_0-aucpr:0.48516
# [99]	validation_0-auc:0.90240	validation_0-aucpr:0.48512
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91     23107
#            1       0.21      0.81      0.34      1232
#
#     accuracy                           0.84     24339
#    macro avg       0.60      0.82      0.62     24339
# weighted avg       0.95      0.84      0.88     24339
#
# ROC AUC Score: 0.9023969657814378
# PRC AUC Score: 0.4857966587894092

# %%
# Define XGBoost hyperparameters to search
xgboost_params = {
    'subsample': [0.9, 1],
    'learning_rate': [0.1, 0.3],
    'max_depth': [5, 6]
}

# Call the XGBoost classification function
xgboost_grid_search = xgboost_classification(X_train, y_train, X_test, y_test, xgboost_params)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# c:\Users\jonas\anaconda3\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.83537	validation_0-aucpr:0.26560
# [1]	validation_0-auc:0.84266	validation_0-aucpr:0.28683
# [2]	validation_0-auc:0.84826	validation_0-aucpr:0.30437
# [3]	validation_0-auc:0.85117	validation_0-aucpr:0.31760
# [4]	validation_0-auc:0.85621	validation_0-aucpr:0.33730
# [5]	validation_0-auc:0.85725	validation_0-aucpr:0.34103
# [6]	validation_0-auc:0.85795	validation_0-aucpr:0.34278
# [7]	validation_0-auc:0.86044	validation_0-aucpr:0.35524
# [8]	validation_0-auc:0.86379	validation_0-aucpr:0.36541
# [9]	validation_0-auc:0.86590	validation_0-aucpr:0.37296
# [10]	validation_0-auc:0.86844	validation_0-aucpr:0.37736
# [11]	validation_0-auc:0.87089	validation_0-aucpr:0.39051
# [12]	validation_0-auc:0.87175	validation_0-aucpr:0.39313
# [13]	validation_0-auc:0.87280	validation_0-aucpr:0.39797
# [14]	validation_0-auc:0.87365	validation_0-aucpr:0.40125
# [15]	validation_0-auc:0.87470	validation_0-aucpr:0.40652
# [16]	validation_0-auc:0.87551	validation_0-aucpr:0.40963
# [17]	validation_0-auc:0.87714	validation_0-aucpr:0.41347
# [18]	validation_0-auc:0.87766	validation_0-aucpr:0.41580
# [19]	validation_0-auc:0.87906	validation_0-aucpr:0.42261
# [20]	validation_0-auc:0.88000	validation_0-aucpr:0.42473
# [21]	validation_0-auc:0.88075	validation_0-aucpr:0.42631
# [22]	validation_0-auc:0.88192	validation_0-aucpr:0.43033
# [23]	validation_0-auc:0.88251	validation_0-aucpr:0.43159
# [24]	validation_0-auc:0.88350	validation_0-aucpr:0.43385
# [25]	validation_0-auc:0.88415	validation_0-aucpr:0.43614
# [26]	validation_0-auc:0.88489	validation_0-aucpr:0.43786
# [27]	validation_0-auc:0.88552	validation_0-aucpr:0.44051
# [28]	validation_0-auc:0.88655	validation_0-aucpr:0.44201
# [29]	validation_0-auc:0.88747	validation_0-aucpr:0.44413
# [30]	validation_0-auc:0.88804	validation_0-aucpr:0.44733
# [31]	validation_0-auc:0.88890	validation_0-aucpr:0.44892
# [32]	validation_0-auc:0.88966	validation_0-aucpr:0.45104
# [33]	validation_0-auc:0.89059	validation_0-aucpr:0.45352
# [34]	validation_0-auc:0.89134	validation_0-aucpr:0.45440
# [35]	validation_0-auc:0.89173	validation_0-aucpr:0.45698
# [36]	validation_0-auc:0.89252	validation_0-aucpr:0.45835
# [37]	validation_0-auc:0.89277	validation_0-aucpr:0.45974
# [38]	validation_0-auc:0.89340	validation_0-aucpr:0.46141
# [39]	validation_0-auc:0.89400	validation_0-aucpr:0.46358
# [40]	validation_0-auc:0.89413	validation_0-aucpr:0.46443
# [41]	validation_0-auc:0.89450	validation_0-aucpr:0.46480
# [42]	validation_0-auc:0.89482	validation_0-aucpr:0.46581
# [43]	validation_0-auc:0.89532	validation_0-aucpr:0.46727
# [44]	validation_0-auc:0.89596	validation_0-aucpr:0.46876
# [45]	validation_0-auc:0.89662	validation_0-aucpr:0.47023
# [46]	validation_0-auc:0.89694	validation_0-aucpr:0.47014
# [47]	validation_0-auc:0.89734	validation_0-aucpr:0.47178
# [48]	validation_0-auc:0.89767	validation_0-aucpr:0.47207
# [49]	validation_0-auc:0.89816	validation_0-aucpr:0.47356
# [50]	validation_0-auc:0.89841	validation_0-aucpr:0.47414
# [51]	validation_0-auc:0.89863	validation_0-aucpr:0.47410
# [52]	validation_0-auc:0.89872	validation_0-aucpr:0.47574
# [53]	validation_0-auc:0.89914	validation_0-aucpr:0.47597
# [54]	validation_0-auc:0.89922	validation_0-aucpr:0.47580
# [55]	validation_0-auc:0.89939	validation_0-aucpr:0.47683
# [56]	validation_0-auc:0.89962	validation_0-aucpr:0.47761
# [57]	validation_0-auc:0.89974	validation_0-aucpr:0.47710
# [58]	validation_0-auc:0.89973	validation_0-aucpr:0.47756
# [59]	validation_0-auc:0.89993	validation_0-aucpr:0.47848
# [60]	validation_0-auc:0.90012	validation_0-aucpr:0.47838
# [61]	validation_0-auc:0.90046	validation_0-aucpr:0.48001
# [62]	validation_0-auc:0.90059	validation_0-aucpr:0.48045
# [63]	validation_0-auc:0.90071	validation_0-aucpr:0.48092
# [64]	validation_0-auc:0.90095	validation_0-aucpr:0.48122
# [65]	validation_0-auc:0.90107	validation_0-aucpr:0.48093
# [66]	validation_0-auc:0.90121	validation_0-aucpr:0.48091
# [67]	validation_0-auc:0.90156	validation_0-aucpr:0.48218
# [68]	validation_0-auc:0.90172	validation_0-aucpr:0.48329
# [69]	validation_0-auc:0.90178	validation_0-aucpr:0.48333
# [70]	validation_0-auc:0.90179	validation_0-aucpr:0.48353
# [71]	validation_0-auc:0.90195	validation_0-aucpr:0.48382
# [72]	validation_0-auc:0.90211	validation_0-aucpr:0.48439
# [73]	validation_0-auc:0.90222	validation_0-aucpr:0.48452
# [74]	validation_0-auc:0.90233	validation_0-aucpr:0.48502
# [75]	validation_0-auc:0.90272	validation_0-aucpr:0.48533
# [76]	validation_0-auc:0.90281	validation_0-aucpr:0.48595
# [77]	validation_0-auc:0.90321	validation_0-aucpr:0.48613
# [78]	validation_0-auc:0.90340	validation_0-aucpr:0.48657
# [79]	validation_0-auc:0.90334	validation_0-aucpr:0.48646
# [80]	validation_0-auc:0.90362	validation_0-aucpr:0.48695
# [81]	validation_0-auc:0.90363	validation_0-aucpr:0.48723
# [82]	validation_0-auc:0.90394	validation_0-aucpr:0.48813
# [83]	validation_0-auc:0.90391	validation_0-aucpr:0.48831
# [84]	validation_0-auc:0.90405	validation_0-aucpr:0.48830
# [85]	validation_0-auc:0.90413	validation_0-aucpr:0.48855
# [86]	validation_0-auc:0.90435	validation_0-aucpr:0.48895
# [87]	validation_0-auc:0.90450	validation_0-aucpr:0.48909
# [88]	validation_0-auc:0.90445	validation_0-aucpr:0.48813
# [89]	validation_0-auc:0.90459	validation_0-aucpr:0.48876
# [90]	validation_0-auc:0.90455	validation_0-aucpr:0.48860
# [91]	validation_0-auc:0.90470	validation_0-aucpr:0.48882
# [92]	validation_0-auc:0.90477	validation_0-aucpr:0.48944
# [93]	validation_0-auc:0.90489	validation_0-aucpr:0.48995
# [94]	validation_0-auc:0.90492	validation_0-aucpr:0.48971
# [95]	validation_0-auc:0.90508	validation_0-aucpr:0.49018
# [96]	validation_0-auc:0.90521	validation_0-aucpr:0.49047
# [97]	validation_0-auc:0.90544	validation_0-aucpr:0.49069
# [98]	validation_0-auc:0.90554	validation_0-aucpr:0.49102
# [99]	validation_0-auc:0.90573	validation_0-aucpr:0.49159
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91     23107
#            1       0.21      0.81      0.34      1232
#
#     accuracy                           0.84     24339
#    macro avg       0.60      0.83      0.62     24339
# weighted avg       0.95      0.84      0.88     24339
#
# ROC AUC Score: 0.905725267235037
# PRC AUC Score: 0.4919209203058949

# %%
xgboost_grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 6, 'subsample': 1}

# %%
# Define XGBoost hyperparameters to search
xgboost_params = {
    'subsample': [0.8, 1],
    'learning_rate': [0.05, 0.1],
    'max_depth': [4, 6]
}

# Call the XGBoost classification function
xgboost_grid_search = xgboost_classification(X_train, y_train, X_test, y_test, xgboost_params)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# c:\Users\jonas\anaconda3\Lib\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.83537	validation_0-aucpr:0.26560
# [1]	validation_0-auc:0.84266	validation_0-aucpr:0.28683
# [2]	validation_0-auc:0.84826	validation_0-aucpr:0.30437
# [3]	validation_0-auc:0.85117	validation_0-aucpr:0.31760
# [4]	validation_0-auc:0.85621	validation_0-aucpr:0.33730
# [5]	validation_0-auc:0.85725	validation_0-aucpr:0.34103
# [6]	validation_0-auc:0.85795	validation_0-aucpr:0.34278
# [7]	validation_0-auc:0.86044	validation_0-aucpr:0.35524
# [8]	validation_0-auc:0.86379	validation_0-aucpr:0.36541
# [9]	validation_0-auc:0.86590	validation_0-aucpr:0.37296
# [10]	validation_0-auc:0.86844	validation_0-aucpr:0.37736
# [11]	validation_0-auc:0.87089	validation_0-aucpr:0.39051
# [12]	validation_0-auc:0.87175	validation_0-aucpr:0.39313
# [13]	validation_0-auc:0.87280	validation_0-aucpr:0.39797
# [14]	validation_0-auc:0.87365	validation_0-aucpr:0.40125
# [15]	validation_0-auc:0.87470	validation_0-aucpr:0.40652
# [16]	validation_0-auc:0.87551	validation_0-aucpr:0.40963
# [17]	validation_0-auc:0.87714	validation_0-aucpr:0.41347
# [18]	validation_0-auc:0.87766	validation_0-aucpr:0.41580
# [19]	validation_0-auc:0.87906	validation_0-aucpr:0.42261
# [20]	validation_0-auc:0.88000	validation_0-aucpr:0.42473
# [21]	validation_0-auc:0.88075	validation_0-aucpr:0.42631
# [22]	validation_0-auc:0.88192	validation_0-aucpr:0.43033
# [23]	validation_0-auc:0.88251	validation_0-aucpr:0.43159
# [24]	validation_0-auc:0.88350	validation_0-aucpr:0.43385
# [25]	validation_0-auc:0.88415	validation_0-aucpr:0.43614
# [26]	validation_0-auc:0.88489	validation_0-aucpr:0.43786
# [27]	validation_0-auc:0.88552	validation_0-aucpr:0.44051
# [28]	validation_0-auc:0.88655	validation_0-aucpr:0.44201
# [29]	validation_0-auc:0.88747	validation_0-aucpr:0.44413
# [30]	validation_0-auc:0.88804	validation_0-aucpr:0.44733
# [31]	validation_0-auc:0.88890	validation_0-aucpr:0.44892
# [32]	validation_0-auc:0.88966	validation_0-aucpr:0.45104
# [33]	validation_0-auc:0.89059	validation_0-aucpr:0.45352
# [34]	validation_0-auc:0.89134	validation_0-aucpr:0.45440
# [35]	validation_0-auc:0.89173	validation_0-aucpr:0.45698
# [36]	validation_0-auc:0.89252	validation_0-aucpr:0.45835
# [37]	validation_0-auc:0.89277	validation_0-aucpr:0.45974
# [38]	validation_0-auc:0.89340	validation_0-aucpr:0.46141
# [39]	validation_0-auc:0.89400	validation_0-aucpr:0.46358
# [40]	validation_0-auc:0.89413	validation_0-aucpr:0.46443
# [41]	validation_0-auc:0.89450	validation_0-aucpr:0.46480
# [42]	validation_0-auc:0.89482	validation_0-aucpr:0.46581
# [43]	validation_0-auc:0.89532	validation_0-aucpr:0.46727
# [44]	validation_0-auc:0.89596	validation_0-aucpr:0.46876
# [45]	validation_0-auc:0.89662	validation_0-aucpr:0.47023
# [46]	validation_0-auc:0.89694	validation_0-aucpr:0.47014
# [47]	validation_0-auc:0.89734	validation_0-aucpr:0.47178
# [48]	validation_0-auc:0.89767	validation_0-aucpr:0.47207
# [49]	validation_0-auc:0.89816	validation_0-aucpr:0.47356
# [50]	validation_0-auc:0.89841	validation_0-aucpr:0.47414
# [51]	validation_0-auc:0.89863	validation_0-aucpr:0.47410
# [52]	validation_0-auc:0.89872	validation_0-aucpr:0.47574
# [53]	validation_0-auc:0.89914	validation_0-aucpr:0.47597
# [54]	validation_0-auc:0.89922	validation_0-aucpr:0.47580
# [55]	validation_0-auc:0.89939	validation_0-aucpr:0.47683
# [56]	validation_0-auc:0.89962	validation_0-aucpr:0.47761
# [57]	validation_0-auc:0.89974	validation_0-aucpr:0.47710
# [58]	validation_0-auc:0.89973	validation_0-aucpr:0.47756
# [59]	validation_0-auc:0.89993	validation_0-aucpr:0.47848
# [60]	validation_0-auc:0.90012	validation_0-aucpr:0.47838
# [61]	validation_0-auc:0.90046	validation_0-aucpr:0.48001
# [62]	validation_0-auc:0.90059	validation_0-aucpr:0.48045
# [63]	validation_0-auc:0.90071	validation_0-aucpr:0.48092
# [64]	validation_0-auc:0.90095	validation_0-aucpr:0.48122
# [65]	validation_0-auc:0.90107	validation_0-aucpr:0.48093
# [66]	validation_0-auc:0.90121	validation_0-aucpr:0.48091
# [67]	validation_0-auc:0.90156	validation_0-aucpr:0.48218
# [68]	validation_0-auc:0.90172	validation_0-aucpr:0.48329
# [69]	validation_0-auc:0.90178	validation_0-aucpr:0.48333
# [70]	validation_0-auc:0.90179	validation_0-aucpr:0.48353
# [71]	validation_0-auc:0.90195	validation_0-aucpr:0.48382
# [72]	validation_0-auc:0.90211	validation_0-aucpr:0.48439
# [73]	validation_0-auc:0.90222	validation_0-aucpr:0.48452
# [74]	validation_0-auc:0.90233	validation_0-aucpr:0.48502
# [75]	validation_0-auc:0.90272	validation_0-aucpr:0.48533
# [76]	validation_0-auc:0.90281	validation_0-aucpr:0.48595
# [77]	validation_0-auc:0.90321	validation_0-aucpr:0.48613
# [78]	validation_0-auc:0.90340	validation_0-aucpr:0.48657
# [79]	validation_0-auc:0.90334	validation_0-aucpr:0.48646
# [80]	validation_0-auc:0.90362	validation_0-aucpr:0.48695
# [81]	validation_0-auc:0.90363	validation_0-aucpr:0.48723
# [82]	validation_0-auc:0.90394	validation_0-aucpr:0.48813
# [83]	validation_0-auc:0.90391	validation_0-aucpr:0.48831
# [84]	validation_0-auc:0.90405	validation_0-aucpr:0.48830
# [85]	validation_0-auc:0.90413	validation_0-aucpr:0.48855
# [86]	validation_0-auc:0.90435	validation_0-aucpr:0.48895
# [87]	validation_0-auc:0.90450	validation_0-aucpr:0.48909
# [88]	validation_0-auc:0.90445	validation_0-aucpr:0.48813
# [89]	validation_0-auc:0.90459	validation_0-aucpr:0.48876
# [90]	validation_0-auc:0.90455	validation_0-aucpr:0.48860
# [91]	validation_0-auc:0.90470	validation_0-aucpr:0.48882
# [92]	validation_0-auc:0.90477	validation_0-aucpr:0.48944
# [93]	validation_0-auc:0.90489	validation_0-aucpr:0.48995
# [94]	validation_0-auc:0.90492	validation_0-aucpr:0.48971
# [95]	validation_0-auc:0.90508	validation_0-aucpr:0.49018
# [96]	validation_0-auc:0.90521	validation_0-aucpr:0.49047
# [97]	validation_0-auc:0.90544	validation_0-aucpr:0.49069
# [98]	validation_0-auc:0.90554	validation_0-aucpr:0.49102
# [99]	validation_0-auc:0.90573	validation_0-aucpr:0.49159
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91     23107
#            1       0.21      0.81      0.34      1232
#
#     accuracy                           0.84     24339
#    macro avg       0.60      0.83      0.62     24339
# weighted avg       0.95      0.84      0.88     24339
#
# ROC AUC Score: 0.905725267235037
# PRC AUC Score: 0.4919209203058949

# %%
xgboost_grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 6, 'subsample': 1}
